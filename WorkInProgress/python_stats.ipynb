# %% [markdown]
# # Mean
#
# $\mu(x)=\frac{1}{n}\sum_{k=1}^{n}x_{k}$

# %% [markdown]
# # Variance
#
# ${\sigma}^{2}(x)=\frac{1}{n-1}\sum_{k=1}^{n}(x_{k}-\mu(x))^2$

# %% [markdown]
# # Standard Deviation
# $\sigma(x)=({\sigma}^2(x))^{1/2}$

# %% [markdown]
# # Mode

# %% [markdown]
# # Median
